# %% [markdown]
# # AMIML — Data Analysis & Synthesis**Systematic Review of Post-Hoc Model-Agnostic Interpretability Methods (2020–2025)**This notebook reproduces all tables and figures reported in §4 of the paper.  It imports analysis functions from the `amiml` package (`src/amiml/`).## Setup

# %%
import syssys.path.insert(0, "../src")from amiml.analysis import run_allfrom amiml import plots# Run the full synthesis pipelineresults = run_all("../data/DB.xlsx", sheet_name="DATA_EXTRACTION")print("Pipeline complete. Sections:", list(results.keys()))

# %% [markdown]
# ---## §4.2 — Descriptive Landscape (RQ1)Publication volume, citation profile, and outlet distribution.

# %%
# Citation statisticsresults["4.2"]["stats"]

# %%
# Papers per yearplots.plot_year_counts(results["4.2"]["year_counts"])results["4.2"]["year_counts"]

# %%
# Publisher / outlet proxyplots.plot_publisher_proxy(results["4.2"]["publisher_proxy"])results["4.2"]["publisher_proxy"]

# %%
# Top-10 most citedresults["4.2"]["top_cited"]

# %% [markdown]
# ---## §4.3 — Method Characterisation (RQ2–RQ3)Scope (Local/Global), output families, and theoretical foundations.

# %%
# Scope distributionplots.plot_scope(results["4.3"]["scope_counts"])results["4.3"]["scope_counts"]

# %%
# Output familiesplots.plot_output_families(results["4.3"]["output_family_counts"])results["4.3"]["output_family_counts"]

# %%
# Theoretical foundations (top terms)results["4.3"]["foundation_top"].head(20)

# %% [markdown]
# ---## §4.4 — Data / Tasks / Domains / Datasets (RQ4)

# %%
# Data modalitiesplots.plot_data_types(results["4.4"]["data_counts"])results["4.4"]["data_counts"]

# %%
# Task typesplots.plot_task_types(results["4.4"]["task_counts"])results["4.4"]["task_counts"]

# %%
# Data × Task cross-tabulationplots.plot_data_task_heatmap(results["4.4"]["crosstab_data_task"])results["4.4"]["crosstab_data_task"]

# %%
# Top domains and datasetsprint("=== Top Domains ===")display(results["4.4"]["domain_top"].head(10))print("\n=== Top Datasets ===")display(results["4.4"]["datasets_top"].head(10))

# %% [markdown]
# ---## §4.5 — Evaluation Practice (RQ5)Quantitative metrics, qualitative criteria, and coverage.

# %%
# Top-15 quantitative metricsplots.plot_quant_top15(results["4.5"]["quant_top"])results["4.5"]["quant_top"].head(15)

# %%
# Top-10 qualitative metricsplots.plot_qual_top10(results["4.5"]["qual_top_10"])results["4.5"]["qual_top_10"]

# %%
# Qualitative evaluation coverageresults["4.5"]["qual_presence"]

# %% [markdown]
# ---## §4.6 — Human Feedback (RQ6)

# %%
# Human feedback prevalenceplots.plot_human_feedback(results["4.6"]["feedback_counts"])results["4.6"]["feedback_counts"]

# %%
# Cross-tabulation: output family × human feedbackresults["4.6"]["cross_output_feedback"]

# %% [markdown]
# ---## §4.7 — Normative / Ethical / Regulatory Themes (RQ7)

# %%
# Ethical themesplots.plot_ethical_themes(results["4.7"])results["4.7"]

# %% [markdown]
# ---## §4.8 — Limitations and Challenges (RQ8)

# %%
# Limitation themesresults["4.8"]
